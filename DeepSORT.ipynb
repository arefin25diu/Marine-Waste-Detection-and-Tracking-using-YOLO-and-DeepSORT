# %%
# !cp '/content/drive/MyDrive/Ocean Plastic YOLO/runs.zip' /content/runs.zip
# !unzip -q '/content/runs.zip' -d '/content/runs'
# Out:
# cp: cannot stat '/content/drive/MyDrive/Ocean Plastic YOLO/runs.zip': No such file or directory
# unzip:  cannot find or open /content/runs.zip, /content/runs.zip.zip or /content/runs.zip.ZIP.

# %%
# !cp runs/content/runs/detect/train2/weights/best.pt /content/model.pt
# Out:
# cp: cannot stat 'runs/content/runs/detect/train2/weights/best.pt': No such file or directory

# %%
# !wget https://www.scidb.cn/previewResult/mp4/21ff/dd8f/efdf/05643bef985fd5b369ee/21ffdd8fefdf05643bef985fd5b369ee.mp4 -O test.mp4
# Out:
# --2025-11-25 07:06:04--  https://www.scidb.cn/previewResult/mp4/21ff/dd8f/efdf/05643bef985fd5b369ee/21ffdd8fefdf05643bef985fd5b369ee.mp4
# Resolving www.scidb.cn (www.scidb.cn)... 155.102.130.185
# Connecting to www.scidb.cn (www.scidb.cn)|155.102.130.185|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4248912 (4.1M) [video/mp4]
# Saving to: ‘test.mp4’
#
# test.mp4            100%[===================>]   4.05M  4.64MB/s    in 0.9s
#
# 2025-11-25 07:06:06 (4.64 MB/s) - ‘test.mp4’ saved [4248912/4248912]

# %%
# !pip install -q ultralytics opencv-python torch numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.4 MB/s eta 0:00:00

# %%
# !python tracker.py --model model.pt --video test.mp4 --output tracked_video.mp4 --no-display
# Out:
# python3: can't open file '/content/tracker.py': [Errno 2] No such file or directory

# %%
from IPython.display import HTML

HTML("""
<video width="320" height="240" controls>
  <source src="/content/tracked_video.mp4" type="video/mp4">
</video>
""")
# Out:
# <video width="320" height="240" controls>
#   <source src="/content/tracked_video.mp4" type="video/mp4">
# </video>
